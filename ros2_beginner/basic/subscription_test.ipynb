# %%
import rclpy as rp
from turtlesim.msg import Pose

# %%
rp.init()

# %%
test_node = rp.create_node('sub_test')

# %%
cnt = 0
def callback(data):
    global cnt
    cnt += 1
    print(">", cnt, " -> X: ", data.x, "Y : ", data.y)

    if cnt > 3:
        raise Exception("Subscription Stop ! ")

# %%
test_node.create_subscription(Pose, "/turtle1/pose", callback, 10)

# %%
rp.spin(test_node)
# Out:
# > 1  -> X:  5.544444561004639 Y :  5.544444561004639
# > 2  -> X:  5.544444561004639 Y :  5.544444561004639
# > 3  -> X:  5.544444561004639 Y :  5.544444561004639
# > 4  -> X:  5.544444561004639 Y :  5.544444561004639
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 rp.spin(test_node)
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/__init__.py:229, in spin(node, executor)
#     227     executor.add_node(node)
#     228     while executor.context.ok():
# --> 229         executor.spin_once()
#     230 finally:
#     231     executor.remove_node(node)
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:808, in SingleThreadedExecutor.spin_once(self, timeout_sec)
#     807 def spin_once(self, timeout_sec: float = None) -> None:
# --> 808     self._spin_once_impl(timeout_sec)
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:805, in SingleThreadedExecutor._spin_once_impl(self, timeout_sec)
#     803 handler()
#     804 if handler.exception() is not None:
# --> 805     raise handler.exception()
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/task.py:272, in Task._execute_coroutine_step(self, coro)
#     270 """Execute or resume a coroutine task."""
#     271 try:
# --> 272     result = coro.send(None)
#     273 except StopIteration as e:
#     274     # The coroutine finished; store the result
#     275     self.set_result(e.value)
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:488, in Executor._make_handler.<locals>.handler(entity, gc, is_shutdown, work_tracker)
#     485     pass
#     487 try:
# --> 488     await call_coroutine(entity, arg)
#     489 finally:
#     490     entity.callback_group.ending_execution(entity)
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:407, in Executor._execute_subscription(self, sub, msg)
#     405 async def _execute_subscription(self, sub, msg):
#     406     if msg:
# --> 407         await await_or_execute(sub.callback, msg)
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:110, in await_or_execute(callback, *args)
#     107     return await callback(*args)
#     108 else:
#     109     # Call a normal function
# --> 110     return callback(*args)
#
# Cell In[4], line 8, in callback(data)
#       5 print(">", cnt, " -> X: ", data.x, "Y : ", data.y)
#       7 if cnt > 3:
# ----> 8     raise Exception("Subscription Stop ! ")
#
# Exception: Subscription Stop !
